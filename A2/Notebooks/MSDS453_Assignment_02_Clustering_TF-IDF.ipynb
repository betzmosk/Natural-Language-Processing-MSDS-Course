# %%
import nltk
import re

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import gensim

from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.manifold import TSNE

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Gensim</b> is a Python library for topic modelling, document indexing and similarity retrieval with large corpora. Target audience is the natural language processing (NLP) and information retrieval (IR) community <br><br>
#     <b>https://pypi.org/project/gensim/ </b>
# </div>

# %%
print("Genism Version: ", gensim.__version__)
# Out:
# Genism Version:  4.3.2

# %%
sns.set_context('talk')

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
def add_movie_descriptor(data: pd.DataFrame, corpus_df: pd.DataFrame):
    """
    Adds "Movie Description" to the supplied dataframe, in the form {Genre}_{P|N}_{Movie Title}_{DocID}
    """
    review = np.where(corpus_df['Review Type (pos or neg)'] == 'Positive', 'P', 'N')
    data['Descriptor'] = corpus_df['Genre of Movie'] + '_' + corpus_df['Movie Title'] + '_' + review + '_' + corpus_df['Doc_ID'].astype(str)

def get_corpus_df(path):
    data = pd.read_csv(path, encoding="utf-8")
    add_movie_descriptor(data, data)
    sorted_data = data.sort_values(['Descriptor'])
    indexed_data = sorted_data.set_index(['Doc_ID'])
    indexed_data['Doc_ID'] = indexed_data.index
    return indexed_data

# %% [markdown]
# # Data

# %%
CORPUS_PATH=\
'https://raw.githubusercontent.com/barrycforever/MSDS_453_Public/main/MSDS453_ClassCorpus/MSDS453_ClassCorpus_Final_Sec57_v2_20230928.csv'
class_corpus = get_corpus_df(CORPUS_PATH)

# %%
class_corpus.loc[class_corpus['Student Name'] == 'BYM']
# Out:
#                     DSI_Title  \
# Doc_ID
# 152      BYM_Doc3_EQUILIBRIUM
# 155      BYM_Doc6_EQUILIBRIUM
# 156      BYM_Doc7_EQUILIBRIUM
# 157      BYM_Doc8_EQUILIBRIUM
# 158      BYM_Doc9_EQUILIBRIUM
# 150      BYM_Doc1_EQUILIBRIUM
# 151      BYM_Doc2_EQUILIBRIUM
# 153      BYM_Doc4_EQUILIBRIUM
# 154      BYM_Doc5_EQUILIBRIUM
# 159     BYM_Doc10_EQUILIBRIUM
#
#                                                      Text  \
# Doc_ID
# 152     A tedious rip-off sci-fi film , itching to be ...
# 155     `` Equilibrium '' is like a remake of `` 1984 ...
# 156     An unsophisticated sci-fi drama that takes its...
# 157     Science fiction is a good genre for creating v...
# 158     The worst theatrically released sci-fi flick s...
# 150     Equilibrium is my favorite movie of 2002 . It ...
# 151     If I was to explain this movie to someone in o...
# 153     If you were disappointed by recent sci-fi acti...
# 154     `` Equilibrium '' would be a mindless action p...
# 159     In the first years of the 21st century , a thi...
#
#          Submission File Name Student Name Genre of Movie  \
# Doc_ID
# 152      BYM_Doc3_EQUILIBRIUM          BYM         Sci-Fi
# 155      BYM_Doc6_EQUILIBRIUM          BYM         Sci-Fi
# 156      BYM_Doc7_EQUILIBRIUM          BYM         Sci-Fi
# 157      BYM_Doc8_EQUILIBRIUM          BYM         Sci-Fi
# 158      BYM_Doc9_EQUILIBRIUM          BYM         Sci-Fi
# 150      BYM_Doc1_EQUILIBRIUM          BYM         Sci-Fi
# 151      BYM_Doc2_EQUILIBRIUM          BYM         Sci-Fi
# 153      BYM_Doc4_EQUILIBRIUM          BYM         Sci-Fi
# 154      BYM_Doc5_EQUILIBRIUM          BYM         Sci-Fi
# 159     BYM_Doc10_EQUILIBRIUM          BYM         Sci-Fi
#
#        Review Type (pos or neg)  Movie Title                Descriptor  Doc_ID
# Doc_ID
# 152                    Negative  EQUILIBRIUM  Sci-Fi_EQUILIBRIUM_N_152     152
# 155                    Negative  EQUILIBRIUM  Sci-Fi_EQUILIBRIUM_N_155     155
# 156                    Negative  EQUILIBRIUM  Sci-Fi_EQUILIBRIUM_N_156     156
# 157                    Negative  EQUILIBRIUM  Sci-Fi_EQUILIBRIUM_N_157     157
# 158                    Negative  EQUILIBRIUM  Sci-Fi_EQUILIBRIUM_N_158     158
# 150                    Positive  EQUILIBRIUM  Sci-Fi_EQUILIBRIUM_P_150     150
# 151                    Positive  EQUILIBRIUM  Sci-Fi_EQUILIBRIUM_P_151     151
# 153                    Positive  EQUILIBRIUM  Sci-Fi_EQUILIBRIUM_P_153     153
# 154                    Positive  EQUILIBRIUM  Sci-Fi_EQUILIBRIUM_P_154     154
# 159                    Positive  EQUILIBRIUM  Sci-Fi_EQUILIBRIUM_P_159     159

# %%
class_corpus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 90 to 164
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DSI_Title                 200 non-null    object
#  1   Text                      200 non-null    object
#  2   Submission File Name      200 non-null    object
#  3   Student Name              200 non-null    object
#  4   Genre of Movie            200 non-null    object
#  5   Review Type (pos or neg)  200 non-null    object
#  6   Movie Title               200 non-null    object
#  7   Descriptor                200 non-null    object
#  8   Doc_ID                    200 non-null    int64
# dtypes: int64(1), object(8)
# memory usage: 15.6+ KB

# %% [markdown]
# # Preprocessing

# %%
STOP_WORDS = set(nltk.corpus.stopwords.words('english'))

# %%
def remove_punctuation(text):
    return re.sub('[^a-zA-Z]', ' ', str(text))

def lower_case(text):
    return text.lower()

def remove_tags(text):
    return re.sub("&lt;/?.*?&gt;"," &lt;&gt; ", text)

def remove_special_chars_and_digits(text):
    return re.sub("(\\d|\\W)+"," ", text)

def remove_stop_words(tokenized_text):
    return [w for w in tokenized_text if not w in STOP_WORDS]

# %%
def normalize(input_text):
    '''
    Normalization involves the following steps:
    1. Remove punctuation
    2. Lower case all words
    3. Remove tags (i.e., HTML tags)
    4. Remove all special characters and digits
    '''
    text = remove_punctuation(input_text)
    text = lower_case(text)
    text = remove_tags(text)
    text = remove_special_chars_and_digits(text)

    return text

# %%
def tokenize(text):
    '''
    Tokenization involves the following steps:
    1. Break text down to tokens (i.e., words separated by white spaces)
    2. Remove stop words from the tokens generated in step 1
    '''
    tokens = nltk.word_tokenize(text)
    tokenized_text = remove_stop_words(tokens)

    return tokenized_text

# %%
def lemmatize(tokenized_text, lemmatizer=WordNetLemmatizer()):
    '''
    Lemmatization is applied to each word in the list of normalized tokens
    (stop words are removed)
    '''
    return [lemmatizer.lemmatize(word) for word in tokenized_text]

# %%
def join_tokens(lemmatized_tokens):
    return ' '.join(lemmatized_tokens)

# %%
class_corpus['normalized_review'] = class_corpus['Text'].apply(normalize)
class_corpus['tokenized_review'] = class_corpus['normalized_review'].apply(tokenize)
class_corpus['lemmatized_tokens'] = class_corpus['tokenized_review'].apply(lemmatize)
class_corpus['lemmatized_text'] = class_corpus['lemmatized_tokens'].apply(join_tokens)

# %%
class_corpus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 90 to 164
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DSI_Title                 200 non-null    object
#  1   Text                      200 non-null    object
#  2   Submission File Name      200 non-null    object
#  3   Student Name              200 non-null    object
#  4   Genre of Movie            200 non-null    object
#  5   Review Type (pos or neg)  200 non-null    object
#  6   Movie Title               200 non-null    object
#  7   Descriptor                200 non-null    object
#  8   Doc_ID                    200 non-null    int64
#  9   normalized_review         200 non-null    object
#  10  tokenized_review          200 non-null    object
#  11  lemmatized_tokens         200 non-null    object
#  12  lemmatized_text           200 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 21.9+ KB

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# ## Method 1: TF-IDF

# %%
tfidf_vectorizer = TfidfVectorizer()

# %%
dtm_class_corpus = tfidf_vectorizer.fit_transform(class_corpus['lemmatized_text'])

# %%
features_tfidf_scores = pd.DataFrame(dtm_class_corpus.toarray(),
                                     columns=tfidf_vectorizer.get_feature_names_out(),
                                     index=class_corpus.index)

# %%
features_tfidf_scores.shape
# Out:
# (200, 10079)

# %% [markdown]
# ## Method 2: Doc2Vec

# %%
documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(class_corpus.lemmatized_tokens)]

# %%
model_doc2vec = Doc2Vec(documents,
                        vector_size=200,
                        min_count=1,
                        workers=4)

# %%
features_doc2vec = pd.DataFrame()

for document in documents:
    vector = pd.DataFrame(model_doc2vec.infer_vector(document.words)).transpose()
    features_doc2vec = pd.concat([features_doc2vec, vector])

# %%
features_doc2vec.shape
# Out:
# (200, 200)

# %% [markdown]
# # Clustering

# %% [markdown]
# Before clustering, we need to scale the data to bring parity between all the columns.

# %%
model_kmeans = KMeans(n_clusters=4,
                      random_state=20130810)

# %%
model_kmeans.fit(features_tfidf_scores)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=20130810)

# %%
labels_kmeans = model_kmeans.labels_

# %% [markdown]
# Quality of clustering is determined using the [silhouette score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html).

# %%
silhouette_score(features_tfidf_scores, labels_kmeans)
# Out:
# 0.019668506687197263

# %%
for k in range(4,25):

    model_kmeans = KMeans(n_clusters=k,
                          random_state=20130810,
                          n_init=10)
    model_kmeans.fit(features_tfidf_scores)
    sil_score = silhouette_score(features_tfidf_scores, model_kmeans.labels_)
    print(f"k = {k}, silhouette score = {sil_score}")
# Out:
# k = 4, silhouette score = 0.019668506687197263
# k = 5, silhouette score = 0.01960948951231668
# k = 6, silhouette score = 0.03140399184887442
# k = 7, silhouette score = 0.030679677109909317
# k = 8, silhouette score = 0.041477133408044944
# k = 9, silhouette score = 0.04220688104713725
# k = 10, silhouette score = 0.04928389483691101
# k = 11, silhouette score = 0.05400954196311141
# k = 12, silhouette score = 0.05879499844161368
# k = 13, silhouette score = 0.06583386328630603
# k = 14, silhouette score = 0.06806265894142115
# k = 15, silhouette score = 0.0698769060334262
# k = 16, silhouette score = 0.076198185612013
# k = 17, silhouette score = 0.07602053681596678
# k = 18, silhouette score = 0.07430469467469758
# k = 19, silhouette score = 0.08229959626398092
# k = 20, silhouette score = 0.07702906824571222
# k = 21, silhouette score = 0.07942200433804138
# k = 22, silhouette score = 0.0805084680432455
# k = 23, silhouette score = 0.078803218247925
# k = 24, silhouette score = 0.07595023025549798

# %%
model_kmeans = KMeans(n_clusters=19)
model_kmeans.fit(features_tfidf_scores)
labels_kmeans = model_kmeans.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
model_tsne = TSNE(n_components=2)

# %%
transformed_values = model_tsne.fit_transform(features_tfidf_scores)
X, Y = [], []

for value in transformed_values:
    X.append(value[0])
    Y.append(value[1])

# %%
plt.figure(figsize=(18, 9))

titles = class_corpus['Movie Title'].to_list()
clusters_kmeans_str = pd.Series(labels_kmeans.astype(str), name='cluster')
labels_kmeans_str = pd.Series(titles, name='Movie Title')

sns.scatterplot(x=X,
                y=Y,
                hue=clusters_kmeans_str,
                hue_order=[str(i) for i in range(0, 20)],
                style=labels_kmeans_str);

plt.legend(bbox_to_anchor=(1.05, 0.5), loc='center left', title='Legend', borderaxespad=0., ncol=2)
plt.title('K-Means Clustering Using TF-IDF Vectors')
plt.show()

# %% [markdown]
# Once the cluster assignment is done, we can then look at the composition of the clusters to qualitatively assess the clusters.

# %%
documents_by_cluster = (class_corpus.loc[:, ['DSI_Title', 'Genre of Movie', 'Text']]
                                    .assign(cluster_label=labels_kmeans))

# %%
documents_by_cluster.query(f"cluster_label == 1")
# Out:
#                        DSI_Title Genre of Movie  \
# Doc_ID
# 50       BKG_Doc1_No_Time_to_Die         Action
# 51       BKG_Doc2_No_Time_to_Die         Action
# 57       BKG_Doc8_No_Time_to_Die         Action
# 58       BKG_Doc9_No_Time_to_Die         Action
# 59      BKG_Doc10_No_Time_to_Die         Action
# 52       BKG_Doc3_No_Time_to_Die         Action
# 53       BKG_Doc4_No_Time_to_Die         Action
# 54       BKG_Doc5_No_Time_to_Die         Action
# 55       BKG_Doc6_No_Time_to_Die         Action
# 56       BKG_Doc7_No_Time_to_Die         Action
#
#                                                      Text  cluster_label
# Doc_ID
# 50      Let the mourning begin . In No Time to Die , J...              1
# 51      For those whose cinematic consciousness predat...              1
# 57      Nothing can truly kill James Bond , but the CO...              1
# 58      Not long into No Time to Die , James Bond ( Da...              1
# 59      Perhaps it is only fitting that , at the end o...              1
# 52      The caretakers of the Intellectual Property kn...              1
# 53      From `` Lawrence of Arabia '' to `` Iron Man ,...              1
# 54      It 's been more than a year since No Time to D...              1
# 55      James Bond has always had a loose relationship...              1
# 56      As Robert Graves wrote when he was ridding him...              1

# %%
pd.set_option('display.max_rows', None)
documents_by_cluster.sort_values(by=['cluster_label', 'Genre of Movie', 'DSI_Title'], ascending=True)
# Out:
#                           DSI_Title Genre of Movie  \
# Doc_ID
# 99       LKP_Doc10_Angel_has_fallen         Action
# 90        LKP_Doc1_Angel_has_fallen         Action
# 91        LKP_Doc2_Angel_has_fallen         Action
# 92        LKP_Doc3_Angel_has_fallen         Action
# 93        LKP_Doc4_Angel_has_fallen         Action
# 94        LKP_Doc5_Angel_has_fallen         Action
# 95        LKP_Doc6_Angel_has_fallen         Action
# 96        LKP_Doc7_Angel_has_fallen         Action
# 97        LKP_Doc8_Angel_has_fallen         Action
# 98        LKP_Doc9_Angel_has_fallen         Action
# 59         BKG_Doc10_No_Time_to_Die         Action
# 50          BKG_Doc1_No_Time_to_Die         Action
# 51          BKG_Doc2_No_Time_to_Die         Action
# 52          BKG_Doc3_No_Time_to_Die         Action
# 53          BKG_Doc4_No_Time_to_Die         Action
# 54          BKG_Doc5_No_Time_to_Die         Action
# 55          BKG_Doc6_No_Time_to_Die         Action
# 56          BKG_Doc7_No_Time_to_Die         Action
# 57          BKG_Doc8_No_Time_to_Die         Action
# 58          BKG_Doc9_No_Time_to_Die         Action
# 74                   DHB_Doc5_Taken         Action
# 75                   DHB_Doc6_Taken         Action
# 77                   DHB_Doc8_Taken         Action
# 81               SHR_Doc2_Inception         Action
# 86               SHR_Doc7_Inception         Action
# 66                    VGI_Doc7_Taxi         Action
# 25           JCT_Doc6_Dirty_Grandpa         Comedy
# 38                  KDB_Doc9_Barbie         Comedy
# 126          OZP_Doc7_TheConjuring2         Horror
# 154            BYM_Doc5_EQUILIBRIUM         Sci-Fi
# 158            BYM_Doc9_EQUILIBRIUM         Sci-Fi
# 49               MDO_Doc10_LostCity         Comedy
# 40                MDO_Doc1_LostCity         Comedy
# 41                MDO_Doc2_LostCity         Comedy
# 42                MDO_Doc3_LostCity         Comedy
# 43                MDO_Doc4_LostCity         Comedy
# 44                MDO_Doc5_LostCity         Comedy
# 45                MDO_Doc6_LostCity         Comedy
# 46                MDO_Doc7_LostCity         Comedy
# 47                MDO_Doc8_LostCity         Comedy
# 48                MDO_Doc9_LostCity         Comedy
# 39                 KDB_Doc10_Barbie         Comedy
# 30                  KDB_Doc1_Barbie         Comedy
# 31                  KDB_Doc2_Barbie         Comedy
# 32                  KDB_Doc3_Barbie         Comedy
# 33                  KDB_Doc4_Barbie         Comedy
# 34                  KDB_Doc5_Barbie         Comedy
# 35                  KDB_Doc6_Barbie         Comedy
# 36                  KDB_Doc7_Barbie         Comedy
# 37                  KDB_Doc8_Barbie         Comedy
# 189              AVR_Doc10_Oblivion         Sci-Fi
# 180               AVR_Doc1_Oblivion         Sci-Fi
# 181               AVR_Doc2_Oblivion         Sci-Fi
# 182               AVR_Doc3_Oblivion         Sci-Fi
# 183               AVR_Doc4_Oblivion         Sci-Fi
# 184               AVR_Doc5_Oblivion         Sci-Fi
# 185               AVR_Doc6_Oblivion         Sci-Fi
# 186               AVR_Doc7_Oblivion         Sci-Fi
# 187               AVR_Doc8_Oblivion         Sci-Fi
# 188               AVR_Doc9_Oblivion         Sci-Fi
# 199           MKW_Doc10_Pitch_Black         Sci-Fi
# 190            MKW_Doc1_Pitch_Black         Sci-Fi
# 191            MKW_Doc2_Pitch_Black         Sci-Fi
# 192            MKW_Doc3_Pitch_Black         Sci-Fi
# 193            MKW_Doc4_Pitch_Black         Sci-Fi
# 194            MKW_Doc5_Pitch_Black         Sci-Fi
# 195            MKW_Doc6_Pitch_Black         Sci-Fi
# 196            MKW_Doc7_Pitch_Black         Sci-Fi
# 197            MKW_Doc8_Pitch_Black         Sci-Fi
# 198            MKW_Doc9_Pitch_Black         Sci-Fi
# 71                   DHB_Doc2_Taken         Action
# 72                   DHB_Doc3_Taken         Action
# 9              XOY_Doc10_Mean_Girls         Comedy
# 0               XOY_Doc1_Mean_Girls         Comedy
# 1               XOY_Doc2_Mean_Girls         Comedy
# 2               XOY_Doc3_Mean_Girls         Comedy
# 3               XOY_Doc4_Mean_Girls         Comedy
# 4               XOY_Doc5_Mean_Girls         Comedy
# 5               XOY_Doc6_Mean_Girls         Comedy
# 6               XOY_Doc7_Mean_Girls         Comedy
# 7               XOY_Doc8_Mean_Girls         Comedy
# 8               XOY_Doc9_Mean_Girls         Comedy
# 149                 CMM_Doc10_Fresh         Horror
# 140                  CMM_Doc1_Fresh         Horror
# 141                  CMM_Doc2_Fresh         Horror
# 142                  CMM_Doc3_Fresh         Horror
# 143                  CMM_Doc4_Fresh         Horror
# 144                  CMM_Doc5_Fresh         Horror
# 145                  CMM_Doc6_Fresh         Horror
# 146                  CMM_Doc7_Fresh         Horror
# 147                  CMM_Doc8_Fresh         Horror
# 148                  CMM_Doc9_Fresh         Horror
# 119            HAK_Doc10_The_Others         Horror
# 110             HAK_Doc1_The_Others         Horror
# 111             HAK_Doc2_The_Others         Horror
# 112             HAK_Doc3_The_Others         Horror
# 114             HAK_Doc5_The_Others         Horror
# 115             HAK_Doc6_The_Others         Horror
# 116             HAK_Doc7_The_Others         Horror
# 117             HAK_Doc8_The_Others         Horror
# 118             HAK_Doc9_The_Others         Horror
# 109        UAJ_Doc10_It_Chapter_Two         Horror
# 100         UAJ_Doc1_It_Chapter_Two         Horror
# 101         UAJ_Doc2_It_Chapter_Two         Horror
# 102         UAJ_Doc3_It_Chapter_Two         Horror
# 103         UAJ_Doc4_It_Chapter_Two         Horror
# 104         UAJ_Doc5_It_Chapter_Two         Horror
# 105         UAJ_Doc6_It_Chapter_Two         Horror
# 106         UAJ_Doc7_It_Chapter_Two         Horror
# 107         UAJ_Doc8_It_Chapter_Two         Horror
# 108         UAJ_Doc9_It_Chapter_Two         Horror
# 89              SHR_Doc10_Inception         Action
# 80               SHR_Doc1_Inception         Action
# 82               SHR_Doc3_Inception         Action
# 83               SHR_Doc4_Inception         Action
# 84               SHR_Doc5_Inception         Action
# 85               SHR_Doc6_Inception         Action
# 87               SHR_Doc8_Inception         Action
# 88               SHR_Doc9_Inception         Action
# 19      HBI_Doc10_Holmes_and_Watson         Comedy
# 10       HBI_Doc1_Holmes_and_Watson         Comedy
# 11       HBI_Doc2_Holmes_and_Watson         Comedy
# 12       HBI_Doc3_Holmes_and_Watson         Comedy
# 13       HBI_Doc4_Holmes_and_Watson         Comedy
# 14       HBI_Doc5_Holmes_and_Watson         Comedy
# 15       HBI_Doc6_Holmes_and_Watson         Comedy
# 16       HBI_Doc7_Holmes_and_Watson         Comedy
# 17       HBI_Doc8_Holmes_and_Watson         Comedy
# 18       HBI_Doc9_Holmes_and_Watson         Comedy
# 139       JLL_Doc10_Drag_Me_To_Hell         Horror
# 130        JLL_Doc1_Drag_Me_To_Hell         Horror
# 131        JLL_Doc2_Drag_Me_To_Hell         Horror
# 132        JLL_Doc3_Drag_Me_To_Hell         Horror
# 133        JLL_Doc4_Drag_Me_To_Hell         Horror
# 134        JLL_Doc5_Drag_Me_To_Hell         Horror
# 135        JLL_Doc6_Drag_Me_To_Hell         Horror
# 136        JLL_Doc7_Drag_Me_To_Hell         Horror
# 137        JLL_Doc8_Drag_Me_To_Hell         Horror
# 138        JLL_Doc9_Drag_Me_To_Hell         Horror
# 29          JCT_Doc10_Dirty_Grandpa         Comedy
# 20           JCT_Doc1_Dirty_Grandpa         Comedy
# 21           JCT_Doc2_Dirty_Grandpa         Comedy
# 22           JCT_Doc3_Dirty_Grandpa         Comedy
# 23           JCT_Doc4_Dirty_Grandpa         Comedy
# 24           JCT_Doc5_Dirty_Grandpa         Comedy
# 26           JCT_Doc7_Dirty_Grandpa         Comedy
# 27           JCT_Doc8_Dirty_Grandpa         Comedy
# 28           JCT_Doc9_Dirty_Grandpa         Comedy
# 79                  DHB_Doc10_Taken         Action
# 70                   DHB_Doc1_Taken         Action
# 73                   DHB_Doc4_Taken         Action
# 76                   DHB_Doc7_Taken         Action
# 78                   DHB_Doc9_Taken         Action
# 69                   VGI_Doc10_Taxi         Action
# 60                    VGI_Doc1_Taxi         Action
# 61                    VGI_Doc2_Taxi         Action
# 62                    VGI_Doc3_Taxi         Action
# 63                    VGI_Doc4_Taxi         Action
# 64                    VGI_Doc5_Taxi         Action
# 65                    VGI_Doc6_Taxi         Action
# 67                    VGI_Doc8_Taxi         Action
# 68                    VGI_Doc9_Taxi         Action
# 152            BYM_Doc3_EQUILIBRIUM         Sci-Fi
# 153            BYM_Doc4_EQUILIBRIUM         Sci-Fi
# 172        DSM_Doc3_Minority_Report         Sci-Fi
# 159           BYM_Doc10_EQUILIBRIUM         Sci-Fi
# 150            BYM_Doc1_EQUILIBRIUM         Sci-Fi
# 155            BYM_Doc6_EQUILIBRIUM         Sci-Fi
# 156            BYM_Doc7_EQUILIBRIUM         Sci-Fi
# 157            BYM_Doc8_EQUILIBRIUM         Sci-Fi
# 179       DSM_Doc10_Minority_Report         Sci-Fi
# 170        DSM_Doc1_Minority_Report         Sci-Fi
# 171        DSM_Doc2_Minority_Report         Sci-Fi
# 173        DSM_Doc4_Minority_Report         Sci-Fi
# 174        DSM_Doc5_Minority_Report         Sci-Fi
# 175        DSM_Doc6_Minority_Report         Sci-Fi
# 176        DSM_Doc7_Minority_Report         Sci-Fi
# 177        DSM_Doc8_Minority_Report         Sci-Fi
# 178        DSM_Doc9_Minority_Report         Sci-Fi
# 113             HAK_Doc4_The_Others         Horror
# 129         OZP_Doc10_TheConjuring2         Horror
# 120          OZP_Doc1_TheConjuring2         Horror
# 121          OZP_Doc2_TheConjuring2         Horror
# 122          OZP_Doc3_TheConjuring2         Horror
# 123          OZP_Doc4_TheConjuring2         Horror
# 124          OZP_Doc5_TheConjuring2         Horror
# 125          OZP_Doc6_TheConjuring2         Horror
# 127          OZP_Doc8_TheConjuring2         Horror
# 128          OZP_Doc9_TheConjuring2         Horror
# 151            BYM_Doc2_EQUILIBRIUM         Sci-Fi
# 169            MEM_Doc10_The_Batman         Sci-Fi
# 160             MEM_Doc1_The_Batman         Sci-Fi
# 161             MEM_Doc2_The_Batman         Sci-Fi
# 162             MEM_Doc3_The_Batman         Sci-Fi
# 163             MEM_Doc4_The_Batman         Sci-Fi
# 164             MEM_Doc5_The_Batman         Sci-Fi
# 165             MEM_Doc6_The_Batman         Sci-Fi
# 166             MEM_Doc7_The_Batman         Sci-Fi
# 167             MEM_Doc8_The_Batman         Sci-Fi
# 168             MEM_Doc9_The_Batman         Sci-Fi
#
#                                                      Text  cluster_label
# Doc_ID
# 99      The `` Has Fallen '' series , `` Olympus , '' ...              0
# 90      Target is on the move . '' Heavily outnumbered...              0
# 91      The sleepy , dopey action bonanza `` Angel Has...              0
# 92      `` Angel Has Fallen '' marks the third time th...              0
# 93      Improving through blandness . So Mike Banning ...              0
# 94      This review may contain spoilers . Angel Has F...              0
# 95      As I left the theater the other night , I bega...              0
# 96      Angel Has Fallen may not be appreciably better...              0
# 97      Gerard Butler continues to burnish his brand o...              0
# 98      American movie presidents can only make us wis...              0
# 59      Perhaps it is only fitting that , at the end o...              1
# 50      Let the mourning begin . In No Time to Die , J...              1
# 51      For those whose cinematic consciousness predat...              1
# 52      The caretakers of the Intellectual Property kn...              1
# 53      From `` Lawrence of Arabia '' to `` Iron Man ,...              1
# 54      It 's been more than a year since No Time to D...              1
# 55      James Bond has always had a loose relationship...              1
# 56      As Robert Graves wrote when he was ridding him...              1
# 57      Nothing can truly kill James Bond , but the CO...              1
# 58      Not long into No Time to Die , James Bond ( Da...              1
# 74      Alright , I watched the movie about a few week...              2
# 75      Remember that time period when Hollywood used ...              2
# 77      As you all know I am very rarely wrong ( note ...              2
# 81      This has to be Christopher Nolan 's best film ...              2
# 86      I have to say to make such an impressive trail...              2
# 66      This has to be the biggest pile of pap i have ...              2
# 25      I really do n't have a problem with any genre ...              2
# 38      While it may serve as a rudimentary reminder o...              2
# 126     James Wan , you motherfucker . I forgot that g...              2
# 154     `` Equilibrium '' would be a mindless action p...              2
# 158     The worst theatrically released sci-fi flick s...              2
# 49      We are curious which writer or director forced...              3
# 40      The Lost City isnt an especially unique film ;...              3
# 41      Loretta Sage ( Sandra Bullock ) is an academic...              3
# 42      The Lost City scratches that particular Channi...              3
# 43      The Lost City is every bit the romantic advent...              3
# 44      As superhero films strengthened their grip on ...              3
# 45      Prolific and reclusive romance novelist Lorett...              3
# 46      Romantic schlock , no matter how cliched or tr...              3
# 47      If you squint , you might recognise a slew of ...              3
# 48      Am not sure what director brothers Adam Nee , ...              3
# 39      Such an incredible steaming pile of liberal ga...              4
# 30      An Unforgettable Delight ! Oh , where do I eve...              4
# 31      A Mesmerizing and Modern Masterpiece : The 202...              4
# 32      I saw this movie with my youngest daughter , 1...              4
# 33      it 's amazing . of course , i would be biased ...              4
# 34      When I first heard a Barbie movie was in the w...              4
# 35      Just watched this today and honestly I do n't ...              4
# 36      It 's a shame because I love Little Women and ...              4
# 37      I did not understand this movie at all . It ha...              4
# 189     What 's the difference between a derivative kn...              5
# 180     If nothing else , `` Oblivion '' will go down ...              5
# 181     If only it were less easy to laugh at Oblivion...              5
# 182     Although Universals publicity department has a...              5
# 183     Only recently , Tom Cruise looked as if he was...              5
# 184     In December , Tom Cruise starred as the title ...              5
# 185     `` Oblivion '' looks marvelous , in the delici...              5
# 186     A sort of The Eternal Return played out in the...              5
# 187     Oblivion will make you remember , not forget ....              5
# 188     The picture is of course a vehicle for Tom Cru...              5
# 199     `` Pitch Black '' is the first movie I 've see...              6
# 190     `` Need you standing by my side , because I 'm...              6
# 191     Packed with razzle-dazzle special effects and ...              6
# 192     Pitch Black is one of my favorite science fict...              6
# 193     `` Pitch Black '' is a pretty solid blend of a...              6
# 194     About Monsters ... Pitch Black was n't about t...              6
# 195     If you ever wondered what it might feel like t...              6
# 196     Pitch Black is action science-fiction that bar...              6
# 197     This sci-fi horror flick is at its best simula...              6
# 198     When a spaceship crash-lands on a planet of th...              6
# 71      I 've never written a review before , but this...              7
# 72      Poor Liam . He 's ex-CIA , which we find out w...              7
# 9       'Gretchen , stop trying to make 'fetch ' happe...              7
# 0       `` In a wasteland of dumb movies about teenage...              7
# 1       Although Mean Girls is likely to be frequently...              7
# 2       She is immediately befriended by two of North ...              7
# 3       Mean Girls '' is somewhat of a phenomenon in t...              7
# 4       The tagline for this movie - Watch Your Back -...              7
# 5       Mean Girls looks and feels like a 2000s comedy...              7
# 6       Teenage Cady Heron ( Lindsay Lohan ) was educa...              7
# 7       Fans who found teen star Lindsay Lohan 's last...              7
# 8       When 16-year-old Cady ( Lindsay Lohan ) first ...              7
# 149     Noa hates dating , and who can blame her ? All...              8
# 140     Sebastian Stan plays an entrepreneurial serial...              8
# 141     You 'd be forgiven for assuming that a movie c...              8
# 142     You do n't need a master 's degree in horror t...              8
# 143     Modern dating can make a girl feel like a real...              8
# 144     Modern dating is banal and dehumanizing . The ...              8
# 145     In the new film Fresh ( Hulu , March 4 ) we wa...              8
# 146     There 's something about a horror film that ta...              8
# 147     With romance callously sliced up into right an...              8
# 148     Daisy Edgar-Jones sure can pick 'em . The dece...              8
# 119     An ambitious disappointment , `` The Others ''...              9
# 110     Many films have toyed with the idea of psychol...              9
# 111     For most of us cinephiles , we remember the fi...              9
# 112     There 's a slightly chill , studied quality to...              9
# 114     If you 're going to steal , steal from the bes...              9
# 115     We knew it would only be a matter of time befo...              9
# 116     The Others starts auspiciously enough with a b...              9
# 117     A Gothic mom-in-distress thriller for those wh...              9
# 118     `` The Others '' is a haunted house mystery --...              9
# 109     `` Should we be running ? '' asks Jessica Chas...             10
# 100     In the wake of the record-breaking success of ...             10
# 101     You 've got to hand it to director Andy Muschi...             10
# 102     `` It Chapter Two '' gave me `` Avengers : End...             10
# 103     IS IT WEIRD to say that It : Chapter Two is al...             10
# 104     How many pages does it take for seven kids to ...             10
# 105     When a work you love is adapted to a new mediu...             10
# 106     It Chapter Two is about a group of friends who...             10
# 107     At what point do scary things lose their power...             10
# 108     When a running joke becomes a `` Kick Me '' si...             10
# 89      Christopher Nolan has done some great work . H...             11
# 80      I 'm nearly at a loss for words . Just when yo...             11
# 82      Inception is truly one of a kind . A concept w...             11
# 83      Many of us , not least those who populate the ...             11
# 84      I want this to be a very accurate and very con...             11
# 85      Contrary to the opinions of the deluded army o...             11
# 87      I had the misfortune of choosing to squander b...             11
# 88      Inception is certainly ambitious . And once ag...             11
# 19      Holmes & Watson is probably exactly what I 'd ...             12
# 10      Out of some morbid curiosity , and perhaps a s...             12
# 11      Dear eight-pound , six-ounce , newborn baby Je...             12
# 12      The comedy so execrable that audiences evacuat...             12
# 13      Maybe it 's just the holiday spirit , but I ca...             12
# 14      One of the year 's most critically shellacked ...             12
# 15      There 's a moment during the stunningly abysma...             12
# 16      The start of Holmes & Watson is both cynical a...             12
# 17      The script for what eventually became the simp...             12
# 18      Hooray , it 's the annual return of the `` Mar...             12
# 139     If a one-eyed gypsy with very bad teeth asks y...             13
# 130     The title `` Drag Me to Hell '' offers both li...             13
# 131     When I was in elementary school , we had a cla...             13
# 132     Drag Me To Hell is one wild ride of a movie . ...             13
# 133     In Sam Raimi 's revenge-of-the-gypsy horror fl...             13
# 134     What can you say about a horror film whose tit...             13
# 135     At what point does gleeful cynicism become so ...             13
# 136     The name alone , `` Drag Me to Hell , '' tells...             13
# 137     HORROR is not just for the young , it 's about...             13
# 138     `` Drag Me to Hell '' is a sometimes funny and...             13
# 29      I figure the new Robert De Niro comedy is call...             14
# 20      `` Dirty Grandpa '' is the latest in the line ...             14
# 21      Over the years , medical there have been a var...             14
# 22      If anyone ever wanted to see a raunchy , offen...             14
# 23      In the same vein of `` Remember the Titans , '...             14
# 24      A couple of weeks ago I had the strangest drea...             14
# 26      Okay , I know what you all may be thinking , D...             14
# 27      For those that are lucky enough to still have ...             14
# 28      Dirty Grandpa has an 11 % approval rating on R...             14
# 79      It 's been just too long waiting for an action...             15
# 70      To save you the time in either watching this f...             15
# 73      Maybe I expected more because it 's an issue I...             15
# 76      Since the entire plot of this film is given aw...             15
# 78      The latest rescue-slash-revenge film to hit ou...             15
# 69      A devil may care ex pizza delivery guy becomes...             15
# 60      I normally avoid action films and car chases b...             15
# 61      This is what movies should be like . It is an ...             15
# 62      In my opinion this is the one of the best main...             15
# 63      Maybe French movies are n't that well known in...             15
# 64      I bought this film by accident , not realising...             15
# 65      This is quite simply the french version of US ...             15
# 67      When I rented this movie , I expected it to be...             15
# 68      I had expected this movie to impress me with g...             15
# 152     A tedious rip-off sci-fi film , itching to be ...             15
# 153     If you were disappointed by recent sci-fi acti...             15
# 172     I think some people just write reviews for sit...             15
# 159     In the first years of the 21st century , a thi...             16
# 150     Equilibrium is my favorite movie of 2002 . It ...             16
# 155     `` Equilibrium '' is like a remake of `` 1984 ...             16
# 156     An unsophisticated sci-fi drama that takes its...             16
# 157     Science fiction is a good genre for creating v...             16
# 179     * * * SLIGHT SPOILERS * * * It 's easy to see ...             16
# 170     It 's an open secret : the Oscar is jinxed . S...             16
# 171     Minority Report is the latest film from Stephe...             16
# 173     Steven Spielberg sets Minority Report in the n...             16
# 174     If not for Kurt Wimmer 's fabulous Equilibrium...             16
# 175     Steven Spielberg has made a couple of clunkers...             16
# 176     For a work of speculative or science fiction t...             16
# 177     I recently sat down to watch this movie again ...             16
# 178     Prior to the release of this movie there were ...             16
# 113     Once upon a time on the Isle of Jersey in the ...             17
# 129     God moves in mysterious ways , but the devil m...             17
# 120     In a haunted-house thriller , inanimate object...             17
# 121     Back in 2013 , James Wans The Conjuring repres...             17
# 122     Horror movies often rely on a certain amount o...             17
# 123     What 's worse : Being attacked by a ghost , or...             17
# 124     At one point deep into the slick and undeniabl...             17
# 125     Im no expert on the subject ( thankfully ) but...             17
# 127     After investigating a case of the paranormal o...             17
# 128     Theyre ba-aack . Three years after The Conjuri...             17
# 151     If I was to explain this movie to someone in o...             17
# 169     Somewhere inside The Batman there 's a taut , ...             18
# 160     The Batman is a promise delivered by Matt Reev...             18
# 161     The Batman begins unlike most superhero films ...             18
# 162     The Dark Knight is back in Matt Reeves ' `` Th...             18
# 163     Throughout the evolution of the Batman charact...             18
# 164     Matt Reeves ' The Batman is a meticulously cra...             18
# 165     Riddle me this , movie buffs ! What has a begi...             18
# 166     There are very few things that are still expec...             18
# 167     It 's cause for modest celebration that `` The...             18
# 168     One thing you can say about THE BATMAN without...             18

# %% [markdown]
# # Conclusion

# %% [markdown]
# Quality of features extracted from text (e.g., `tf-idf` and `doc2vec`) can be acertained by the quality of the clusters generated using these features. These clusters also highlight potential patterns within the corpus.

# %%
model_kmeans_genres = KMeans(n_clusters=4,
                      random_state=20130810)

# %%
model_kmeans_genres.fit(features_tfidf_scores)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=20130810)

# %%
labels_kmeans = model_kmeans_genres.labels_

# %%
silhouette_score(features_tfidf_scores, labels_kmeans)
# Out:
# 0.019668506687197263

# %%
for k in range(4, 21):
    model_kmeans = KMeans(n_clusters=k,
                          random_state=20130810,
                          n_init=10)
    model_kmeans.fit(features_tfidf_scores)
    sil_score = silhouette_score(features_tfidf_scores, model_kmeans.labels_)
    print(f"k = {k}, silhouette score = {sil_score}")
# Out:
# k = 4, silhouette score = 0.019668506687197263
# k = 5, silhouette score = 0.01960948951231668
# k = 6, silhouette score = 0.03140399184887442
# k = 7, silhouette score = 0.030679677109909317
# k = 8, silhouette score = 0.041477133408044944
# k = 9, silhouette score = 0.04220688104713725
# k = 10, silhouette score = 0.04928389483691101
# k = 11, silhouette score = 0.05400954196311141
# k = 12, silhouette score = 0.05879499844161368
# k = 13, silhouette score = 0.06583386328630603
# k = 14, silhouette score = 0.06806265894142115
# k = 15, silhouette score = 0.0698769060334262
# k = 16, silhouette score = 0.076198185612013
# k = 17, silhouette score = 0.07602053681596678
# k = 18, silhouette score = 0.07430469467469758
# k = 19, silhouette score = 0.08229959626398092
# k = 20, silhouette score = 0.07702906824571222

# %%
model_tsne = TSNE(n_components=2)
transformed_values = model_tsne.fit_transform(features_tfidf_scores)
X, Y = [], []

for value in transformed_values:
    X.append(value[0])
    Y.append(value[1])

# %%
len(X)
# Out:
# 200

# %%
genres = class_corpus['Genre of Movie'].to_list()
plt.figure(figsize=(18, 9))

labels_kmeans_str = pd.Series(labels_kmeans.astype(str), name='cluster')
genres_kmeans_str = pd.Series(genres, name='genre')

sns.scatterplot(x=X,
                y=Y,
                hue=labels_kmeans_str,
                hue_order=['0', '1', '2', '3'],
                style=genres_kmeans_str);
plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.title('K-Means Clustering For Genre - 4 Clusters')
plt.show()
