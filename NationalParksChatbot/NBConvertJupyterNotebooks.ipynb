# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %%shell
# cd gdrive/MyDrive/Colab\ Notebooks/MSDS453/FinalProject/Notebooks/
# ls
# Out:
#  FinalProjectDataPreparation.ipynb      OpenAI_Chatbot.ipynb
#  MSDS453_Wikipedia_Extract_Code.ipynb   QAModel.ipynb
# 'NLTK-TF-IDF Chatbot.ipynb'	        Sentence_Transformer_Chatbot.ipynb

# %%
# %%shell
# cd gdrive/MyDrive/Colab\ Notebooks/MSDS453/FinalProject/Notebooks/
# for file in *.ipynb; do jupyter nbconvert --to html "$file"; done
# Out:
# [NbConvertApp] Converting notebook FinalProjectDataPreparation.ipynb to html
# [NbConvertApp] Writing 988798 bytes to FinalProjectDataPreparation.html
# [NbConvertApp] Converting notebook MSDS453_Wikipedia_Extract_Code.ipynb to html
# [NbConvertApp] Writing 718899 bytes to MSDS453_Wikipedia_Extract_Code.html
# [NbConvertApp] Converting notebook NLTK-TF-IDF Chatbot.ipynb to html
# [NbConvertApp] Writing 629769 bytes to NLTK-TF-IDF Chatbot.html
# [NbConvertApp] Converting notebook OpenAI_Chatbot.ipynb to html
# [NbConvertApp] Writing 612831 bytes to OpenAI_Chatbot.html
# [NbConvertApp] Converting notebook QAModel.ipynb to html
# Traceback (most recent call last):
#   File "/usr/local/bin/jupyter-nbconvert", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/jupyter_core/application.py", line 280, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
# ...

# %%
# %%shell
# jupyter nbconvert --to html Sentence_Transformer_Chatbot.ipynb
# Out:
# [NbConvertApp] WARNING | pattern 'Sentence_Transformer_Chatbot.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
# ...

# %%
# %%shell
# cd gdrive/MyDrive/Colab\ Notebooks/MSDS453/A3/Notebooks/
# mkdir ../html/
# mv *.html ../html/
# Out:
# /bin/bash: line 1: cd: gdrive/MyDrive/Colab Notebooks/MSDS453/A3/Notebooks/QAModel.ipynb: No such file or directory
# mv: cannot stat '*.html': No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-17-9d9fc856e3ea> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('shell', '', 'cd gdrive/MyDrive/Colab\\ Notebooks/MSDS453/A3/Notebooks/QAModel.ipynb\nmkdir ../html/\nmv *.html ../html/\n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
# ...

# %%
# %%shell
# cd gdrive/MyDrive/Colab\ Notebooks/MSDS453/A3/html/
# ls
# Out:
# dereference_pronouns_from_class_corpus.html
# MSDS453_Assignment_03_LSTM_32_32_Dropout.html
# MSDS453_Assignment_03_LSTM_32_32.html
# MSDS453_Assignment_03_LSTM_32_Dropout.html
# MSDS453_Assignment_03_LSTM_64_64.html
# MSDS453_Assignment_03_LSTM_64_Dropout.html
# MSDS453_Assignment_03_LSTM_64.html
# MSDS453_Assignment_03_SUP00_v03_20231025_KnowledgeGraphs.html
# MSDS453_Assignment_03_SUP00_v03_20231025_KnowledgeGraphs_OpenAI.html
